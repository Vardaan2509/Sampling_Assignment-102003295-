# %% [markdown]
# First we need to balance our dataset

# %%
import pandas as pd
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
df = pd.read_csv('Creditcard_data.csv')

# Separate the target variable and features
X = df.drop('Class', axis=1)
y = df['Class']

# Instantiate a RandomOverSampler object and resample the data
ros = RandomOverSampler(random_state=42)
X_resampled_1, y_resampled_1 = ros.fit_resample(X, y)

# Instantiate a RandomUnderSampler object and resample the data
rus = RandomUnderSampler(random_state=42)
X_resampled_2, y_resampled_2 = rus.fit_resample(X_resampled_1, y_resampled_1)

# Create a new balanced dataframe
df_resampled = pd.concat([X_resampled_2, y_resampled_2], axis=1)

# Save the balanced dataframe to a new CSV file
df_resampled.to_csv('Balanced_data.csv', index=False)

# %%
class_counts = df_resampled['Class'].value_counts()

print("Class distribution:")
print(class_counts)
# Out:
# Class distribution:
# 0    763
# 1    763
# Name: Class, dtype: int64

# %% [markdown]
# Our Data is now balanced

# %% [markdown]
# SIMPLE RANDOM SAMPLING

# %%
from sklearn.model_selection import train_test_split
import math
X1 = df_resampled.drop('Class', axis=1)
y1 = df_resampled['Class']
N = len(df_resampled)
p = 0.5
c = 0.95  # desired confidence level
e = 0.05  # desired margin of error

z = 1.96  # z-score for 95% confidence level
n = math.ceil((z**2 * p * (1-p)) / e**2)

# Set the sample size
sample_size = n  # Set the desired sample size
X_sampled = X1.sample(n=sample_size, random_state=0)
y_sampled = y1[X_sampled.index]  # Match the sampled output variable with the sampled input variables
    
# Combine the sampled input and output variables into a single DataFrame
sampled_df = pd.concat([X_sampled, y_sampled], axis=1)
    
# Save the sampled DataFrame to a CSV file
sampled_df.to_csv(f'simple_random_dataset.csv', index=False)

# %%
#Performing metrics analysis
from pycaret.datasets import get_data
from pycaret.classification import *
DataSet = get_data("simple_random_dataset")
setup(data=DataSet, target='Class', silent=True)
cm = compare_models(include=['rf', 'lr','nb','svm','dt','knn'])
# Out:
# <style type="text/css">
# #T_45456 th {
#   text-align: left;
# }
# #T_45456_row0_col0, #T_45456_row1_col0, #T_45456_row1_col1, #T_45456_row1_col2, #T_45456_row1_col4, #T_45456_row1_col5, #T_45456_row1_col6, #T_45456_row1_col7, #T_45456_row2_col0, #T_45456_row2_col1, #T_45456_row2_col2, #T_45456_row2_col4, #T_45456_row2_col5, #T_45456_row2_col6, #T_45456_row2_col7, #T_45456_row3_col0, #T_45456_row3_col1, #T_45456_row3_col2, #T_45456_row3_col4, #T_45456_row3_col5, #T_45456_row3_col6, #T_45456_row3_col7, #T_45456_row4_col0, #T_45456_row4_col1, #T_45456_row4_col2, #T_45456_row4_col3, #T_45456_row4_col4, #T_45456_row4_col5, #T_45456_row4_col6, #T_45456_row4_col7, #T_45456_row5_col0, #T_45456_row5_col1, #T_45456_row5_col2, #T_45456_row5_col3, #T_45456_row5_col4, #T_45456_row5_col5, #T_45456_row5_col6, #T_45456_row5_col7 {
#   text-align: left;
# }
# #T_45456_row0_col1, #T_45456_row0_col2, #T_45456_row0_col3, #T_45456_row0_col4, #T_45456_row0_col5, #T_45456_row0_col6, #T_45456_row0_col7, #T_45456_row1_col3, #T_45456_row2_col3, #T_45456_row3_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_45456_row0_col8, #T_45456_row1_col8, #T_45456_row2_col8, #T_45456_row3_col8, #T_45456_row5_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_45456_row4_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_45456">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_45456_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_45456_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_45456_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_45456_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_45456_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_45456_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_45456_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_45456_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_45456_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_45456_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_45456_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_45456_row0_col1" class="data row0 col1" >0.9926</td>
#       <td id="T_45456_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_45456_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_45456_row0_col4" class="data row0 col4" >0.9857</td>
#       <td id="T_45456_row0_col5" class="data row0 col5" >0.9926</td>
#       <td id="T_45456_row0_col6" class="data row0 col6" >0.9852</td>
#       <td id="T_45456_row0_col7" class="data row0 col7" >0.9857</td>
#       <td id="T_45456_row0_col8" class="data row0 col8" >0.1380</td>
#     </tr>
#     <tr>
#       <th id="T_45456_level0_row1" class="row_heading level0 row1" >dt</th>
#       <td id="T_45456_row1_col0" class="data row1 col0" >Decision Tree Classifier</td>
#       <td id="T_45456_row1_col1" class="data row1 col1" >0.9704</td>
#       <td id="T_45456_row1_col2" class="data row1 col2" >0.9717</td>
#       <td id="T_45456_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_45456_row1_col4" class="data row1 col4" >0.9442</td>
#       <td id="T_45456_row1_col5" class="data row1 col5" >0.9706</td>
#       <td id="T_45456_row1_col6" class="data row1 col6" >0.9409</td>
#       <td id="T_45456_row1_col7" class="data row1 col7" >0.9438</td>
#       <td id="T_45456_row1_col8" class="data row1 col8" >0.0300</td>
#     </tr>
#     <tr>
#       <th id="T_45456_level0_row2" class="row_heading level0 row2" >lr</th>
#       <td id="T_45456_row2_col0" class="data row2 col0" >Logistic Regression</td>
#       <td id="T_45456_row2_col1" class="data row2 col1" >0.9295</td>
#       <td id="T_45456_row2_col2" class="data row2 col2" >0.9527</td>
#       <td id="T_45456_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_45456_row2_col4" class="data row2 col4" >0.8778</td>
#       <td id="T_45456_row2_col5" class="data row2 col5" >0.9334</td>
#       <td id="T_45456_row2_col6" class="data row2 col6" >0.8598</td>
#       <td id="T_45456_row2_col7" class="data row2 col7" >0.8709</td>
#       <td id="T_45456_row2_col8" class="data row2 col8" >0.0960</td>
#     </tr>
#     <tr>
#       <th id="T_45456_level0_row3" class="row_heading level0 row3" >knn</th>
#       <td id="T_45456_row3_col0" class="data row3 col0" >K Neighbors Classifier</td>
#       <td id="T_45456_row3_col1" class="data row3 col1" >0.9259</td>
#       <td id="T_45456_row3_col2" class="data row3 col2" >0.9717</td>
#       <td id="T_45456_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_45456_row3_col4" class="data row3 col4" >0.8704</td>
#       <td id="T_45456_row3_col5" class="data row3 col5" >0.9294</td>
#       <td id="T_45456_row3_col6" class="data row3 col6" >0.8527</td>
#       <td id="T_45456_row3_col7" class="data row3 col7" >0.8642</td>
#       <td id="T_45456_row3_col8" class="data row3 col8" >0.0170</td>
#     </tr>
#     <tr>
#       <th id="T_45456_level0_row4" class="row_heading level0 row4" >nb</th>
#       <td id="T_45456_row4_col0" class="data row4 col0" >Naive Bayes</td>
#       <td id="T_45456_row4_col1" class="data row4 col1" >0.8256</td>
#       <td id="T_45456_row4_col2" class="data row4 col2" >0.8559</td>
#       <td id="T_45456_row4_col3" class="data row4 col3" >0.7596</td>
#       <td id="T_45456_row4_col4" class="data row4 col4" >0.8623</td>
#       <td id="T_45456_row4_col5" class="data row4 col5" >0.7970</td>
#       <td id="T_45456_row4_col6" class="data row4 col6" >0.6481</td>
#       <td id="T_45456_row4_col7" class="data row4 col7" >0.6635</td>
#       <td id="T_45456_row4_col8" class="data row4 col8" >0.0080</td>
#     </tr>
#     <tr>
#       <th id="T_45456_level0_row5" class="row_heading level0 row5" >svm</th>
#       <td id="T_45456_row5_col0" class="data row5 col0" >SVM - Linear Kernel</td>
#       <td id="T_45456_row5_col1" class="data row5 col1" >0.5168</td>
#       <td id="T_45456_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_45456_row5_col3" class="data row5 col3" >0.6660</td>
#       <td id="T_45456_row5_col4" class="data row5 col4" >0.4053</td>
#       <td id="T_45456_row5_col5" class="data row5 col5" >0.4909</td>
#       <td id="T_45456_row5_col6" class="data row5 col6" >0.0438</td>
#       <td id="T_45456_row5_col7" class="data row5 col7" >0.0521</td>
#       <td id="T_45456_row5_col8" class="data row5 col8" >0.0100</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# STRATIFIED SAMPLING

# %%
import pandas as pd
import numpy as np
import math

# Read the CSV file into a DataFrame
df = pd.read_csv('Balanced_data.csv')

# Separate the feature matrix X and the target variable y
X = df.drop(columns=['Class'])
y = df['Class']

# Determine the number of strata (in this case, we use a binary target variable, so there are two strata)
num_strata = 2

# Initialize an empty list to store the stratified samples
samples = []

# Loop over each stratum
for i in range(num_strata):
    # Subset the data to include only the observations in the current stratum
    stratum_data = df[df['Class'] == i]
    
    # Calculate the sample size for the current stratum
    stratum_size = len(stratum_data)
    population_size = len(df)
    desired_margin_of_error = 0.05
    confidence_level = 0.95
    z_score = 1.96  # for a 95% confidence level
    p = stratum_size / population_size
    q = 1 - p
    n = (z_score**2 * p * q * population_size) / ((z_score**2 * p * q) + (desired_margin_of_error**2 * (population_size-1)))
    n = math.ceil(n)
    
    # If the calculated sample size for the current stratum is greater than the number of observations in the stratum, set the sample size to the number of observations
    if n > stratum_size:
        n = stratum_size
    
    # Randomly select observations from the current stratum to include in the sample
    sample_indices = np.random.choice(stratum_data.index, size=n, replace=False)
    stratum_sample = stratum_data.loc[sample_indices]
    
    # Add the current stratum sample to the list of stratified samples
    samples.append(stratum_sample)

# Combine the stratified samples into a single DataFrame
stratified_sample = pd.concat(samples)

# Write the stratified sample to a new CSV file
stratified_sample.to_csv('stratified_dataset.csv', index=False)

# %%
from pycaret.datasets import get_data
from pycaret.classification import *
DataSet = get_data("stratified_dataset")
setup(data=DataSet, target='Class', silent=True)
cm = compare_models(include=['rf', 'lr','nb','svm','dt','knn'])
# Out:
# <style type="text/css">
# #T_7f3f6 th {
#   text-align: left;
# }
# #T_7f3f6_row0_col0, #T_7f3f6_row1_col0, #T_7f3f6_row1_col1, #T_7f3f6_row1_col2, #T_7f3f6_row1_col4, #T_7f3f6_row1_col5, #T_7f3f6_row1_col6, #T_7f3f6_row1_col7, #T_7f3f6_row2_col0, #T_7f3f6_row2_col1, #T_7f3f6_row2_col2, #T_7f3f6_row2_col4, #T_7f3f6_row2_col5, #T_7f3f6_row2_col6, #T_7f3f6_row2_col7, #T_7f3f6_row3_col0, #T_7f3f6_row3_col1, #T_7f3f6_row3_col2, #T_7f3f6_row3_col4, #T_7f3f6_row3_col5, #T_7f3f6_row3_col6, #T_7f3f6_row3_col7, #T_7f3f6_row4_col0, #T_7f3f6_row4_col1, #T_7f3f6_row4_col2, #T_7f3f6_row4_col3, #T_7f3f6_row4_col4, #T_7f3f6_row4_col5, #T_7f3f6_row4_col6, #T_7f3f6_row4_col7, #T_7f3f6_row5_col0, #T_7f3f6_row5_col1, #T_7f3f6_row5_col2, #T_7f3f6_row5_col3, #T_7f3f6_row5_col4, #T_7f3f6_row5_col5, #T_7f3f6_row5_col6, #T_7f3f6_row5_col7 {
#   text-align: left;
# }
# #T_7f3f6_row0_col1, #T_7f3f6_row0_col2, #T_7f3f6_row0_col3, #T_7f3f6_row0_col4, #T_7f3f6_row0_col5, #T_7f3f6_row0_col6, #T_7f3f6_row0_col7, #T_7f3f6_row1_col3, #T_7f3f6_row2_col3, #T_7f3f6_row3_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_7f3f6_row0_col8, #T_7f3f6_row1_col8, #T_7f3f6_row2_col8, #T_7f3f6_row3_col8, #T_7f3f6_row5_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_7f3f6_row4_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_7f3f6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7f3f6_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7f3f6_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_7f3f6_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_7f3f6_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_7f3f6_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_7f3f6_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_7f3f6_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_7f3f6_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_7f3f6_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f3f6_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_7f3f6_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_7f3f6_row0_col1" class="data row0 col1" >0.9977</td>
#       <td id="T_7f3f6_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_7f3f6_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_7f3f6_row0_col4" class="data row0 col4" >0.9957</td>
#       <td id="T_7f3f6_row0_col5" class="data row0 col5" >0.9978</td>
#       <td id="T_7f3f6_row0_col6" class="data row0 col6" >0.9953</td>
#       <td id="T_7f3f6_row0_col7" class="data row0 col7" >0.9954</td>
#       <td id="T_7f3f6_row0_col8" class="data row0 col8" >0.1440</td>
#     </tr>
#     <tr>
#       <th id="T_7f3f6_level0_row1" class="row_heading level0 row1" >dt</th>
#       <td id="T_7f3f6_row1_col0" class="data row1 col0" >Decision Tree Classifier</td>
#       <td id="T_7f3f6_row1_col1" class="data row1 col1" >0.9884</td>
#       <td id="T_7f3f6_row1_col2" class="data row1 col2" >0.9881</td>
#       <td id="T_7f3f6_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_7f3f6_row1_col4" class="data row1 col4" >0.9783</td>
#       <td id="T_7f3f6_row1_col5" class="data row1 col5" >0.9889</td>
#       <td id="T_7f3f6_row1_col6" class="data row1 col6" >0.9767</td>
#       <td id="T_7f3f6_row1_col7" class="data row1 col7" >0.9772</td>
#       <td id="T_7f3f6_row1_col8" class="data row1 col8" >0.0090</td>
#     </tr>
#     <tr>
#       <th id="T_7f3f6_level0_row2" class="row_heading level0 row2" >knn</th>
#       <td id="T_7f3f6_row2_col0" class="data row2 col0" >K Neighbors Classifier</td>
#       <td id="T_7f3f6_row2_col1" class="data row2 col1" >0.9536</td>
#       <td id="T_7f3f6_row2_col2" class="data row2 col2" >0.9833</td>
#       <td id="T_7f3f6_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_7f3f6_row2_col4" class="data row2 col4" >0.9209</td>
#       <td id="T_7f3f6_row2_col5" class="data row2 col5" >0.9579</td>
#       <td id="T_7f3f6_row2_col6" class="data row2 col6" >0.9069</td>
#       <td id="T_7f3f6_row2_col7" class="data row2 col7" >0.9128</td>
#       <td id="T_7f3f6_row2_col8" class="data row2 col8" >0.0180</td>
#     </tr>
#     <tr>
#       <th id="T_7f3f6_level0_row3" class="row_heading level0 row3" >lr</th>
#       <td id="T_7f3f6_row3_col0" class="data row3 col0" >Logistic Regression</td>
#       <td id="T_7f3f6_row3_col1" class="data row3 col1" >0.9117</td>
#       <td id="T_7f3f6_row3_col2" class="data row3 col2" >0.9273</td>
#       <td id="T_7f3f6_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_7f3f6_row3_col4" class="data row3 col4" >0.8566</td>
#       <td id="T_7f3f6_row3_col5" class="data row3 col5" >0.9218</td>
#       <td id="T_7f3f6_row3_col6" class="data row3 col6" >0.8225</td>
#       <td id="T_7f3f6_row3_col7" class="data row3 col7" >0.8375</td>
#       <td id="T_7f3f6_row3_col8" class="data row3 col8" >0.0890</td>
#     </tr>
#     <tr>
#       <th id="T_7f3f6_level0_row4" class="row_heading level0 row4" >nb</th>
#       <td id="T_7f3f6_row4_col0" class="data row4 col0" >Naive Bayes</td>
#       <td id="T_7f3f6_row4_col1" class="data row4 col1" >0.7429</td>
#       <td id="T_7f3f6_row4_col2" class="data row4 col2" >0.8281</td>
#       <td id="T_7f3f6_row4_col3" class="data row4 col3" >0.6717</td>
#       <td id="T_7f3f6_row4_col4" class="data row4 col4" >0.7945</td>
#       <td id="T_7f3f6_row4_col5" class="data row4 col5" >0.7146</td>
#       <td id="T_7f3f6_row4_col6" class="data row4 col6" >0.4893</td>
#       <td id="T_7f3f6_row4_col7" class="data row4 col7" >0.5004</td>
#       <td id="T_7f3f6_row4_col8" class="data row4 col8" >0.0060</td>
#     </tr>
#     <tr>
#       <th id="T_7f3f6_level0_row5" class="row_heading level0 row5" >svm</th>
#       <td id="T_7f3f6_row5_col0" class="data row5 col0" >SVM - Linear Kernel</td>
#       <td id="T_7f3f6_row5_col1" class="data row5 col1" >0.5198</td>
#       <td id="T_7f3f6_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_7f3f6_row5_col3" class="data row5 col3" >0.5591</td>
#       <td id="T_7f3f6_row5_col4" class="data row5 col4" >0.5074</td>
#       <td id="T_7f3f6_row5_col5" class="data row5 col5" >0.4717</td>
#       <td id="T_7f3f6_row5_col6" class="data row5 col6" >0.0390</td>
#       <td id="T_7f3f6_row5_col7" class="data row5 col7" >0.0196</td>
#       <td id="T_7f3f6_row5_col8" class="data row5 col8" >0.0070</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# CLUSTER SAMPLING

# %%
import pandas as pd
import numpy as np
import math
from sklearn.cluster import KMeans
# Load the data
data = pd.read_csv('Balanced_data.csv')
# Define the cluster size
C = 600
# Calculate the number of clusters
n_clusters = math.ceil(len(data)/C)
# Create a KMeans object with the calculated number of clusters
kmeans = KMeans(n_clusters=n_clusters)
# Fit the KMeans object to the data
kmeans.fit(data.drop('Class', axis=1))
# Add the cluster labels to the data
data['Cluster'] = kmeans.labels_
# Calculate the sample size
z = 1.96
p = 0.5
e = 0.05
s = 1
N = len(data)
C = len(data['Cluster'].unique())
n = math.ceil((z**2 * p * (1-p) * (N/C)) / ((e**2) + ((z**2 * p * (1-p))/(C-1))))

# Create an empty dataframe to hold the sample
sample = pd.DataFrame(columns=data.columns)
# Loop through each cluster
for i in range(n_clusters):
    # Get the data for the current cluster
    cluster_data = data[data['Cluster'] == i]
    # Calculate the cluster sample size
    cluster_size = len(cluster_data)
    cluster_sample_size = math.ceil((cluster_size/N)*n)
    # If the cluster sample size is larger than the cluster size, set it to the cluster size
    if cluster_sample_size > cluster_size:
        cluster_sample_size = cluster_size
    # Sample from the current cluster
    cluster_sample = cluster_data.sample(n=cluster_sample_size, replace=False)    
    # Add the cluster sample to the overall sample dataframe
    sample = pd.concat([sample, cluster_sample])
# Remove the cluster column from the sample
sample = sample.drop('Cluster', axis=1)
# Save the sample to a CSV file
sample.to_csv('cluster_sample_dataset.csv', index=False)

# %%
from pycaret.datasets import get_data
from pycaret.classification import *
DataSet = get_data("cluster_sample_dataset")
setup(data=DataSet, target='Class', silent=True)
cm = compare_models(include=['rf', 'lr','nb','svm','dt','knn'])
# Out:
# <style type="text/css">
# #T_518c8 th {
#   text-align: left;
# }
# #T_518c8_row0_col0, #T_518c8_row1_col0, #T_518c8_row1_col1, #T_518c8_row1_col2, #T_518c8_row1_col4, #T_518c8_row1_col5, #T_518c8_row1_col6, #T_518c8_row1_col7, #T_518c8_row2_col0, #T_518c8_row2_col1, #T_518c8_row2_col2, #T_518c8_row2_col4, #T_518c8_row2_col5, #T_518c8_row2_col6, #T_518c8_row2_col7, #T_518c8_row3_col0, #T_518c8_row3_col1, #T_518c8_row3_col2, #T_518c8_row3_col4, #T_518c8_row3_col5, #T_518c8_row3_col6, #T_518c8_row3_col7, #T_518c8_row4_col0, #T_518c8_row4_col1, #T_518c8_row4_col2, #T_518c8_row4_col3, #T_518c8_row4_col4, #T_518c8_row4_col5, #T_518c8_row4_col6, #T_518c8_row4_col7, #T_518c8_row5_col0, #T_518c8_row5_col1, #T_518c8_row5_col2, #T_518c8_row5_col3, #T_518c8_row5_col4, #T_518c8_row5_col5, #T_518c8_row5_col6, #T_518c8_row5_col7 {
#   text-align: left;
# }
# #T_518c8_row0_col1, #T_518c8_row0_col2, #T_518c8_row0_col3, #T_518c8_row0_col4, #T_518c8_row0_col5, #T_518c8_row0_col6, #T_518c8_row0_col7, #T_518c8_row1_col3, #T_518c8_row2_col3, #T_518c8_row3_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_518c8_row0_col8, #T_518c8_row1_col8, #T_518c8_row2_col8, #T_518c8_row3_col8, #T_518c8_row5_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_518c8_row4_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_518c8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_518c8_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_518c8_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_518c8_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_518c8_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_518c8_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_518c8_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_518c8_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_518c8_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_518c8_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_518c8_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_518c8_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_518c8_row0_col1" class="data row0 col1" >0.9986</td>
#       <td id="T_518c8_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_518c8_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_518c8_row0_col4" class="data row0 col4" >0.9972</td>
#       <td id="T_518c8_row0_col5" class="data row0 col5" >0.9986</td>
#       <td id="T_518c8_row0_col6" class="data row0 col6" >0.9972</td>
#       <td id="T_518c8_row0_col7" class="data row0 col7" >0.9972</td>
#       <td id="T_518c8_row0_col8" class="data row0 col8" >0.1310</td>
#     </tr>
#     <tr>
#       <th id="T_518c8_level0_row1" class="row_heading level0 row1" >dt</th>
#       <td id="T_518c8_row1_col0" class="data row1 col0" >Decision Tree Classifier</td>
#       <td id="T_518c8_row1_col1" class="data row1 col1" >0.9915</td>
#       <td id="T_518c8_row1_col2" class="data row1 col2" >0.9917</td>
#       <td id="T_518c8_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_518c8_row1_col4" class="data row1 col4" >0.9835</td>
#       <td id="T_518c8_row1_col5" class="data row1 col5" >0.9916</td>
#       <td id="T_518c8_row1_col6" class="data row1 col6" >0.9831</td>
#       <td id="T_518c8_row1_col7" class="data row1 col7" >0.9834</td>
#       <td id="T_518c8_row1_col8" class="data row1 col8" >0.0240</td>
#     </tr>
#     <tr>
#       <th id="T_518c8_level0_row2" class="row_heading level0 row2" >knn</th>
#       <td id="T_518c8_row2_col0" class="data row2 col0" >K Neighbors Classifier</td>
#       <td id="T_518c8_row2_col1" class="data row2 col1" >0.9648</td>
#       <td id="T_518c8_row2_col2" class="data row2 col2" >0.9889</td>
#       <td id="T_518c8_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_518c8_row2_col4" class="data row2 col4" >0.9351</td>
#       <td id="T_518c8_row2_col5" class="data row2 col5" >0.9660</td>
#       <td id="T_518c8_row2_col6" class="data row2 col6" >0.9297</td>
#       <td id="T_518c8_row2_col7" class="data row2 col7" >0.9328</td>
#       <td id="T_518c8_row2_col8" class="data row2 col8" >0.0130</td>
#     </tr>
#     <tr>
#       <th id="T_518c8_level0_row3" class="row_heading level0 row3" >lr</th>
#       <td id="T_518c8_row3_col0" class="data row3 col0" >Logistic Regression</td>
#       <td id="T_518c8_row3_col1" class="data row3 col1" >0.9127</td>
#       <td id="T_518c8_row3_col2" class="data row3 col2" >0.9453</td>
#       <td id="T_518c8_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_518c8_row3_col4" class="data row3 col4" >0.8522</td>
#       <td id="T_518c8_row3_col5" class="data row3 col5" >0.9195</td>
#       <td id="T_518c8_row3_col6" class="data row3 col6" >0.8258</td>
#       <td id="T_518c8_row3_col7" class="data row3 col7" >0.8399</td>
#       <td id="T_518c8_row3_col8" class="data row3 col8" >0.1370</td>
#     </tr>
#     <tr>
#       <th id="T_518c8_level0_row4" class="row_heading level0 row4" >nb</th>
#       <td id="T_518c8_row4_col0" class="data row4 col0" >Naive Bayes</td>
#       <td id="T_518c8_row4_col1" class="data row4 col1" >0.7873</td>
#       <td id="T_518c8_row4_col2" class="data row4 col2" >0.8698</td>
#       <td id="T_518c8_row4_col3" class="data row4 col3" >0.7514</td>
#       <td id="T_518c8_row4_col4" class="data row4 col4" >0.8053</td>
#       <td id="T_518c8_row4_col5" class="data row4 col5" >0.7720</td>
#       <td id="T_518c8_row4_col6" class="data row4 col6" >0.5740</td>
#       <td id="T_518c8_row4_col7" class="data row4 col7" >0.5808</td>
#       <td id="T_518c8_row4_col8" class="data row4 col8" >0.0060</td>
#     </tr>
#     <tr>
#       <th id="T_518c8_level0_row5" class="row_heading level0 row5" >svm</th>
#       <td id="T_518c8_row5_col0" class="data row5 col0" >SVM - Linear Kernel</td>
#       <td id="T_518c8_row5_col1" class="data row5 col1" >0.5141</td>
#       <td id="T_518c8_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_518c8_row5_col3" class="data row5 col3" >0.6571</td>
#       <td id="T_518c8_row5_col4" class="data row5 col4" >0.5320</td>
#       <td id="T_518c8_row5_col5" class="data row5 col5" >0.5262</td>
#       <td id="T_518c8_row5_col6" class="data row5 col6" >0.0327</td>
#       <td id="T_518c8_row5_col7" class="data row5 col7" >0.0064</td>
#       <td id="T_518c8_row5_col8" class="data row5 col8" >0.0080</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# SYSTEMATIC SAMPLING

# %%
import pandas as pd
import math

# Load the dataset "Balanced_data" into a Pandas dataframe
df = pd.read_csv("Balanced_data.csv")

# Calculate the number of rows in the dataset
n = len(df)

# Set the sampling interval "k" as the square root of the number of rows in the dataset
k = int(math.sqrt(n))

# Select every "k" row starting from a random index in the dataset
sample = df.iloc[::k]

sample.to_csv('systematic_sample_dataset.csv', index=False)

# %%
from pycaret.datasets import get_data
from pycaret.classification import *
DataSet = get_data("systematic_sample_dataset")
setup(data=DataSet, target='Class', silent=True)
cm = compare_models(include=['rf', 'lr','nb','svm','dt','knn'])
# Out:
# <style type="text/css">
# #T_87fdd th {
#   text-align: left;
# }
# #T_87fdd_row0_col0, #T_87fdd_row1_col0, #T_87fdd_row1_col1, #T_87fdd_row1_col4, #T_87fdd_row1_col5, #T_87fdd_row1_col6, #T_87fdd_row1_col7, #T_87fdd_row2_col0, #T_87fdd_row2_col1, #T_87fdd_row2_col2, #T_87fdd_row2_col4, #T_87fdd_row2_col5, #T_87fdd_row2_col6, #T_87fdd_row2_col7, #T_87fdd_row3_col0, #T_87fdd_row3_col1, #T_87fdd_row3_col2, #T_87fdd_row3_col4, #T_87fdd_row3_col5, #T_87fdd_row3_col6, #T_87fdd_row3_col7, #T_87fdd_row4_col0, #T_87fdd_row4_col1, #T_87fdd_row4_col2, #T_87fdd_row4_col3, #T_87fdd_row4_col4, #T_87fdd_row4_col5, #T_87fdd_row4_col6, #T_87fdd_row4_col7, #T_87fdd_row5_col0, #T_87fdd_row5_col1, #T_87fdd_row5_col2, #T_87fdd_row5_col3, #T_87fdd_row5_col4, #T_87fdd_row5_col5, #T_87fdd_row5_col6, #T_87fdd_row5_col7 {
#   text-align: left;
# }
# #T_87fdd_row0_col1, #T_87fdd_row0_col2, #T_87fdd_row0_col3, #T_87fdd_row0_col4, #T_87fdd_row0_col5, #T_87fdd_row0_col6, #T_87fdd_row0_col7, #T_87fdd_row1_col2, #T_87fdd_row1_col3, #T_87fdd_row2_col3, #T_87fdd_row3_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_87fdd_row0_col8, #T_87fdd_row1_col8, #T_87fdd_row4_col8, #T_87fdd_row5_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_87fdd_row2_col8, #T_87fdd_row3_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_87fdd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_87fdd_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_87fdd_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_87fdd_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_87fdd_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_87fdd_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_87fdd_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_87fdd_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_87fdd_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_87fdd_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_87fdd_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_87fdd_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_87fdd_row0_col1" class="data row0 col1" >0.9500</td>
#       <td id="T_87fdd_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_87fdd_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_87fdd_row0_col4" class="data row0 col4" >0.9500</td>
#       <td id="T_87fdd_row0_col5" class="data row0 col5" >0.9667</td>
#       <td id="T_87fdd_row0_col6" class="data row0 col6" >0.9000</td>
#       <td id="T_87fdd_row0_col7" class="data row0 col7" >0.9000</td>
#       <td id="T_87fdd_row0_col8" class="data row0 col8" >0.1030</td>
#     </tr>
#     <tr>
#       <th id="T_87fdd_level0_row1" class="row_heading level0 row1" >lr</th>
#       <td id="T_87fdd_row1_col0" class="data row1 col0" >Logistic Regression</td>
#       <td id="T_87fdd_row1_col1" class="data row1 col1" >0.9000</td>
#       <td id="T_87fdd_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_87fdd_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_87fdd_row1_col4" class="data row1 col4" >0.8833</td>
#       <td id="T_87fdd_row1_col5" class="data row1 col5" >0.9267</td>
#       <td id="T_87fdd_row1_col6" class="data row1 col6" >0.7400</td>
#       <td id="T_87fdd_row1_col7" class="data row1 col7" >0.7500</td>
#       <td id="T_87fdd_row1_col8" class="data row1 col8" >0.0210</td>
#     </tr>
#     <tr>
#       <th id="T_87fdd_level0_row2" class="row_heading level0 row2" >dt</th>
#       <td id="T_87fdd_row2_col0" class="data row2 col0" >Decision Tree Classifier</td>
#       <td id="T_87fdd_row2_col1" class="data row2 col1" >0.8500</td>
#       <td id="T_87fdd_row2_col2" class="data row2 col2" >0.8000</td>
#       <td id="T_87fdd_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_87fdd_row2_col4" class="data row2 col4" >0.8500</td>
#       <td id="T_87fdd_row2_col5" class="data row2 col5" >0.9067</td>
#       <td id="T_87fdd_row2_col6" class="data row2 col6" >0.6000</td>
#       <td id="T_87fdd_row2_col7" class="data row2 col7" >0.6000</td>
#       <td id="T_87fdd_row2_col8" class="data row2 col8" >0.0060</td>
#     </tr>
#     <tr>
#       <th id="T_87fdd_level0_row3" class="row_heading level0 row3" >nb</th>
#       <td id="T_87fdd_row3_col0" class="data row3 col0" >Naive Bayes</td>
#       <td id="T_87fdd_row3_col1" class="data row3 col1" >0.7667</td>
#       <td id="T_87fdd_row3_col2" class="data row3 col2" >0.8000</td>
#       <td id="T_87fdd_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_87fdd_row3_col4" class="data row3 col4" >0.7500</td>
#       <td id="T_87fdd_row3_col5" class="data row3 col5" >0.8367</td>
#       <td id="T_87fdd_row3_col6" class="data row3 col6" >0.4400</td>
#       <td id="T_87fdd_row3_col7" class="data row3 col7" >0.4500</td>
#       <td id="T_87fdd_row3_col8" class="data row3 col8" >0.0060</td>
#     </tr>
#     <tr>
#       <th id="T_87fdd_level0_row4" class="row_heading level0 row4" >knn</th>
#       <td id="T_87fdd_row4_col0" class="data row4 col0" >K Neighbors Classifier</td>
#       <td id="T_87fdd_row4_col1" class="data row4 col1" >0.7667</td>
#       <td id="T_87fdd_row4_col2" class="data row4 col2" >0.9000</td>
#       <td id="T_87fdd_row4_col3" class="data row4 col3" >0.9000</td>
#       <td id="T_87fdd_row4_col4" class="data row4 col4" >0.8000</td>
#       <td id="T_87fdd_row4_col5" class="data row4 col5" >0.8167</td>
#       <td id="T_87fdd_row4_col6" class="data row4 col6" >0.5300</td>
#       <td id="T_87fdd_row4_col7" class="data row4 col7" >0.5500</td>
#       <td id="T_87fdd_row4_col8" class="data row4 col8" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_87fdd_level0_row5" class="row_heading level0 row5" >svm</th>
#       <td id="T_87fdd_row5_col0" class="data row5 col0" >SVM - Linear Kernel</td>
#       <td id="T_87fdd_row5_col1" class="data row5 col1" >0.5833</td>
#       <td id="T_87fdd_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_87fdd_row5_col3" class="data row5 col3" >0.7000</td>
#       <td id="T_87fdd_row5_col4" class="data row5 col4" >0.6500</td>
#       <td id="T_87fdd_row5_col5" class="data row5 col5" >0.5967</td>
#       <td id="T_87fdd_row5_col6" class="data row5 col6" >0.1600</td>
#       <td id="T_87fdd_row5_col7" class="data row5 col7" >0.2000</td>
#       <td id="T_87fdd_row5_col8" class="data row5 col8" >0.0200</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# CONVENIENCE SAMPLING

# %%
import pandas as pd
import numpy as np

# Load the data
data = pd.read_csv('Balanced_data.csv')

# Calculate the sample size based on practical considerations
n = 200 # Set the desired sample size

# Select a convenience sample from the data
sample = data.sample(n=n, replace=False)

# Save the sample to a CSV file
sample.to_csv('convenience_sample_data.csv', index=False)

# %%
from pycaret.datasets import get_data
from pycaret.classification import *
DataSet = get_data("convenience_sample_data")
setup(data=DataSet, target='Class', silent=True)
cm = compare_models(include=['rf', 'lr','nb','svm','dt','knn'])
# Out:
# <style type="text/css">
# #T_bcbad th {
#   text-align: left;
# }
# #T_bcbad_row0_col0, #T_bcbad_row1_col0, #T_bcbad_row1_col1, #T_bcbad_row1_col2, #T_bcbad_row1_col4, #T_bcbad_row1_col5, #T_bcbad_row1_col6, #T_bcbad_row1_col7, #T_bcbad_row2_col0, #T_bcbad_row2_col1, #T_bcbad_row2_col2, #T_bcbad_row2_col3, #T_bcbad_row2_col4, #T_bcbad_row2_col5, #T_bcbad_row2_col6, #T_bcbad_row2_col7, #T_bcbad_row3_col0, #T_bcbad_row3_col1, #T_bcbad_row3_col2, #T_bcbad_row3_col3, #T_bcbad_row3_col4, #T_bcbad_row3_col5, #T_bcbad_row3_col6, #T_bcbad_row3_col7, #T_bcbad_row4_col0, #T_bcbad_row4_col1, #T_bcbad_row4_col2, #T_bcbad_row4_col3, #T_bcbad_row4_col4, #T_bcbad_row4_col5, #T_bcbad_row4_col6, #T_bcbad_row4_col7, #T_bcbad_row5_col0, #T_bcbad_row5_col1, #T_bcbad_row5_col2, #T_bcbad_row5_col3, #T_bcbad_row5_col4, #T_bcbad_row5_col5, #T_bcbad_row5_col6, #T_bcbad_row5_col7 {
#   text-align: left;
# }
# #T_bcbad_row0_col1, #T_bcbad_row0_col2, #T_bcbad_row0_col3, #T_bcbad_row0_col4, #T_bcbad_row0_col5, #T_bcbad_row0_col6, #T_bcbad_row0_col7, #T_bcbad_row1_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_bcbad_row0_col8, #T_bcbad_row2_col8, #T_bcbad_row3_col8, #T_bcbad_row4_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_bcbad_row1_col8, #T_bcbad_row5_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_bcbad">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bcbad_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_bcbad_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_bcbad_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_bcbad_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_bcbad_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_bcbad_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_bcbad_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_bcbad_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_bcbad_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bcbad_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_bcbad_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_bcbad_row0_col1" class="data row0 col1" >0.9923</td>
#       <td id="T_bcbad_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_bcbad_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_bcbad_row0_col4" class="data row0 col4" >0.9833</td>
#       <td id="T_bcbad_row0_col5" class="data row0 col5" >0.9909</td>
#       <td id="T_bcbad_row0_col6" class="data row0 col6" >0.9843</td>
#       <td id="T_bcbad_row0_col7" class="data row0 col7" >0.9854</td>
#       <td id="T_bcbad_row0_col8" class="data row0 col8" >0.1120</td>
#     </tr>
#     <tr>
#       <th id="T_bcbad_level0_row1" class="row_heading level0 row1" >dt</th>
#       <td id="T_bcbad_row1_col0" class="data row1 col0" >Decision Tree Classifier</td>
#       <td id="T_bcbad_row1_col1" class="data row1 col1" >0.9637</td>
#       <td id="T_bcbad_row1_col2" class="data row1 col2" >0.9694</td>
#       <td id="T_bcbad_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_bcbad_row1_col4" class="data row1 col4" >0.9238</td>
#       <td id="T_bcbad_row1_col5" class="data row1 col5" >0.9587</td>
#       <td id="T_bcbad_row1_col6" class="data row1 col6" >0.9266</td>
#       <td id="T_bcbad_row1_col7" class="data row1 col7" >0.9313</td>
#       <td id="T_bcbad_row1_col8" class="data row1 col8" >0.0060</td>
#     </tr>
#     <tr>
#       <th id="T_bcbad_level0_row2" class="row_heading level0 row2" >lr</th>
#       <td id="T_bcbad_row2_col0" class="data row2 col0" >Logistic Regression</td>
#       <td id="T_bcbad_row2_col1" class="data row2 col1" >0.9121</td>
#       <td id="T_bcbad_row2_col2" class="data row2 col2" >0.9275</td>
#       <td id="T_bcbad_row2_col3" class="data row2 col3" >0.9433</td>
#       <td id="T_bcbad_row2_col4" class="data row2 col4" >0.8612</td>
#       <td id="T_bcbad_row2_col5" class="data row2 col5" >0.8982</td>
#       <td id="T_bcbad_row2_col6" class="data row2 col6" >0.8207</td>
#       <td id="T_bcbad_row2_col7" class="data row2 col7" >0.8270</td>
#       <td id="T_bcbad_row2_col8" class="data row2 col8" >0.0570</td>
#     </tr>
#     <tr>
#       <th id="T_bcbad_level0_row3" class="row_heading level0 row3" >knn</th>
#       <td id="T_bcbad_row3_col0" class="data row3 col0" >K Neighbors Classifier</td>
#       <td id="T_bcbad_row3_col1" class="data row3 col1" >0.8412</td>
#       <td id="T_bcbad_row3_col2" class="data row3 col2" >0.9192</td>
#       <td id="T_bcbad_row3_col3" class="data row3 col3" >0.9433</td>
#       <td id="T_bcbad_row3_col4" class="data row3 col4" >0.7564</td>
#       <td id="T_bcbad_row3_col5" class="data row3 col5" >0.8313</td>
#       <td id="T_bcbad_row3_col6" class="data row3 col6" >0.6857</td>
#       <td id="T_bcbad_row3_col7" class="data row3 col7" >0.7140</td>
#       <td id="T_bcbad_row3_col8" class="data row3 col8" >0.0130</td>
#     </tr>
#     <tr>
#       <th id="T_bcbad_level0_row4" class="row_heading level0 row4" >nb</th>
#       <td id="T_bcbad_row4_col0" class="data row4 col0" >Naive Bayes</td>
#       <td id="T_bcbad_row4_col1" class="data row4 col1" >0.6978</td>
#       <td id="T_bcbad_row4_col2" class="data row4 col2" >0.8494</td>
#       <td id="T_bcbad_row4_col3" class="data row4 col3" >0.3633</td>
#       <td id="T_bcbad_row4_col4" class="data row4 col4" >0.7883</td>
#       <td id="T_bcbad_row4_col5" class="data row4 col5" >0.4807</td>
#       <td id="T_bcbad_row4_col6" class="data row4 col6" >0.3128</td>
#       <td id="T_bcbad_row4_col7" class="data row4 col7" >0.3650</td>
#       <td id="T_bcbad_row4_col8" class="data row4 col8" >0.0090</td>
#     </tr>
#     <tr>
#       <th id="T_bcbad_level0_row5" class="row_heading level0 row5" >svm</th>
#       <td id="T_bcbad_row5_col0" class="data row5 col0" >SVM - Linear Kernel</td>
#       <td id="T_bcbad_row5_col1" class="data row5 col1" >0.4956</td>
#       <td id="T_bcbad_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_bcbad_row5_col3" class="data row5 col3" >0.4700</td>
#       <td id="T_bcbad_row5_col4" class="data row5 col4" >0.2833</td>
#       <td id="T_bcbad_row5_col5" class="data row5 col5" >0.3199</td>
#       <td id="T_bcbad_row5_col6" class="data row5 col6" >-0.0023</td>
#       <td id="T_bcbad_row5_col7" class="data row5 col7" >0.0008</td>
#       <td id="T_bcbad_row5_col8" class="data row5 col8" >0.0060</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Now we are done with the five diffrerent sampling techniques and have calculated various metrics using pycaret for different classification based ML models.
